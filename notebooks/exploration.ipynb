# %%
import pandas as pd

df = pd.read_csv("../data/telemetry.csv")

print(df.shape)
print(df.failure.value_counts())
# Out:
# (10000, 6)
# failure
# 0    9970
# 1      30
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 cpu        memory          disk   temperature       network  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      49.415956     50.452988     50.005039     57.403504    496.863806
# std       28.763013     28.929455     28.677376     21.674594    289.284179
# min        0.001163      0.015774      0.004812     20.000415      0.016736
# 25%       24.632887     25.394580     25.374791     38.514294    244.272222
# 50%       49.252862     50.589678     50.206809     57.502268    493.717192
# 75%       74.000635     75.647922     74.467385     76.033719    750.477034
# max       99.971767     99.992483     99.990098     94.984203    999.972147
#
#             failure
# count  10000.000000
# mean       0.003000
# std        0.054693
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(),annot=True)

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
